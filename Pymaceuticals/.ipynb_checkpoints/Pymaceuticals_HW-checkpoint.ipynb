# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
study_data_complete = pd.merge(study_results, mouse_metadata, on = 'Mouse ID', how = 'left')

# Display the data table for preview
study_data_complete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mice_count = study_data_complete['Mouse ID'].nunique()
mice_count
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse = study_data_complete[study_data_complete.duplicated(['Mouse ID', 'Timepoint'])]
duplicate_mouse
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 137      g989          0           45.000000                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 137   Female          21          26
# 360   Female          21          26
# 681   Female          21          26
# 869   Female          21          26
# 1111  Female          21          26

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_data = study_data_complete.loc[study_data_complete['Mouse ID'] == 'g989']
duplicate_mouse_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_df = study_data_complete.drop(duplicate_mouse_data.index)
cleaned_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
mice_count = cleaned_df['Mouse ID'].nunique()
mice_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

mean = cleaned_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
median = cleaned_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
variance = cleaned_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
stan_dev = cleaned_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
sem = cleaned_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()


# This method is the most straighforward, creating multiple series and putting them all together at the end.
tumor_volume_summary_df = pd.DataFrame({'Mean Tumor Volume' : mean,
                                        'Median Tumor Volume' : median,
                                        'Tumor Volume Variance' : variance,
                                        'Tumor Volume Std. Dev.' : stan_dev,
                                        'Tumor Volume Std. Err.' : sem
                                        })
tumor_volume_summary_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
tumor_volume_summary_df = pd.DataFrame({'Mean Tumor Volume' : mean,
                                        'Median Tumor Volume' : median,
                                        'Tumor Volume Variance' : variance,
                                        'Tumor Volume Std. Dev.' : stan_dev,
                                        'Tumor Volume Std. Err.' : sem
                                        })
tumor_volume_summary_df

# This method produces everything in a single groupby function
regimen_grouped = cleaned_df.groupby(['Drug Regimen'])
aggregated_data = regimen_grouped.agg(['mean','median','var','std','sem'])["Tumor Volume (mm3)"]
aggregated_data
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
mice_count_per_treatment = cleaned_df.groupby(['Drug Regimen']).count()['Mouse ID']

bar_plot_pandas = mice_count_per_treatment.plot.bar(figsize=(7,5), color='b',fontsize = 12)
mice_count_per_treatment
plt.title('Number of Mice Per Treatment', fontsize = 16)
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Mice Tested')

plt.show()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
# Convert drug regimens column to a list
drug_regimens = tumor_volume_summary_df.index.tolist()

# Convert regimen count into a list
regimen_count = (cleaned_df.groupby(['Drug Regimen'])['Mouse ID'].count()).tolist()
regimen_count

# Define x-axis
x_axis = np.arange(len(regimen_count))
x_axis = drug_regimens

# Create bar chart
plt.figure(figsize=(7,5))
plt.bar(x_axis, regimen_count, color='b', align='center')

# Create ticks for x-axis
ticks = ['Capomulin', 'Ceftamin', 'Infubinol', 'Ketapril', 'Naftisol', 'Placebo', 'Propriva', 'Ramicane', 'Stelasyn', 'Zoniferol']
plt.xticks(ticks, drug_regimens, rotation='vertical')

#Label the bar chart
plt.title('Number of Mice Per Treatment')
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Mice Tested')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
# Create new DataFrame grouped by sex
gender_grouped = pd.DataFrame(cleaned_df.groupby(['Sex']).count()).reset_index()
gender_grouped

# Filter DataFrame to only include count of mice by sex
gender_df = gender_grouped[['Sex', 'Mouse ID']]
gender_df

# Create pie chart
labels = 'Female', 'Male'
gender_df.plot.pie(y = 'Mouse ID', labels = labels, autopct="%1.1f%%")
plt.legend(labels, bbox_to_anchor=(0.85,1.025), loc="upper left")
plt.title('Male vs Female Mice Population', fontsize=16)
plt.ylabel('Sex', fontsize=12)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# Create labels for pie plot
labels = 'Female', 'Male'

# Calculate values for each pie chart section
wedges = (cleaned_df.groupby(["Sex"])["Age_months"].count()).tolist()

# Create the pie chart
fig1, ax1 = plt.subplots(figsize=(7,5))
plt.pie(wedges, labels=labels, autopct="%1.1f%%")
plt.title('Male vs Female Mice Population', fontsize=16)
plt.ylabel('Sex', fontsize=12)
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
capomulin_df = cleaned_df.loc[cleaned_df['Drug Regimen'] == 'Capomulin',:]
ramicane_df = cleaned_df.loc[cleaned_df['Drug Regimen'] == 'Ramicane',:]
infubinol_df = cleaned_df.loc[cleaned_df['Drug Regimen'] == 'Infubinol',:]
ceftamin_df = cleaned_df.loc[cleaned_df['Drug Regimen'] == 'Ceftamin',:]

# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# Capomulin
capomulin_last = capomulin_df.groupby(['Mouse ID']).max()['Timepoint']
capomulin_vol = pd.DataFrame(capomulin_last)
capomulin_merge = pd.merge(capomulin_vol, cleaned_df, on=('Mouse ID', 'Timepoint'), how='left')
capomulin_merge.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128         45           38.982878                 2    Capomulin
# 1     b742         45           38.939633                 0    Capomulin
# 2     f966         20           30.485985                 0    Capomulin
# 3     g288         45           37.074024                 1    Capomulin
# 4     g316         45           40.159220                 2    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male           7          21
# 2    Male          16          17
# 3    Male           3          19
# 4  Female          22          22

# %%
# Ramicane
ramicane_last = ramicane_df.groupby(['Mouse ID']).max()['Timepoint']
ramicane_vol = pd.DataFrame(ramicane_last)
ramicane_merge = pd.merge(ramicane_vol, cleaned_df, on=('Mouse ID', 'Timepoint'), how='left')
ramicane_merge.head()
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0      a411         45           38.407618                 1     Ramicane
# 1      a444         45           43.047543                 0     Ramicane
# 2      a520         45           38.810366                 1     Ramicane
# 3      a644         45           32.978522                 1     Ramicane
# 4      c458         30           38.342008                 2     Ramicane
# 5      c758         45           33.397653                 1     Ramicane
# 6      d251         45           37.311236                 2     Ramicane
# 7      e662         45           40.659006                 2     Ramicane
# 8      g791         45           29.128472                 1     Ramicane
# 9      i177         45           33.562402                 3     Ramicane
# 10     i334         45           36.374510                 2     Ramicane
# 11     j913         45           31.560470                 1     Ramicane
# ...

# %%
# Infubinol
infubinol_last = infubinol_df.groupby(['Mouse ID']).max()['Timepoint']
infubinol_vol = pd.DataFrame(infubinol_last)
infubinol_merge = pd.merge(infubinol_vol, cleaned_df, on=('Mouse ID', 'Timepoint'), how='left')
infubinol_merge.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     a203         45           67.973419                 2    Infubinol
# 1     a251         45           65.525743                 1    Infubinol
# 2     a577         30           57.031862                 2    Infubinol
# 3     a685         45           66.083066                 3    Infubinol
# 4     c139         45           72.226731                 2    Infubinol
#
#       Sex  Age_months  Weight (g)
# 0  Female          20          23
# 1  Female          21          25
# 2  Female           6          25
# 3    Male           8          30
# 4    Male          11          28

# %%
# Ceftamin
ceftamin_last = ceftamin_df.groupby(['Mouse ID']).max()['Timepoint']
ceftamin_vol = pd.DataFrame(ceftamin_last)
ceftamin_merge = pd.merge(ceftamin_vol, cleaned_df, on=('Mouse ID', 'Timepoint'), how='left')
ceftamin_merge.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     a275         45           62.999356                 3     Ceftamin
# 1     b447          0           45.000000                 0     Ceftamin
# 2     b487         25           56.057749                 1     Ceftamin
# 3     b759         30           55.742829                 1     Ceftamin
# 4     f436         15           48.722078                 2     Ceftamin
#
#       Sex  Age_months  Weight (g)
# 0  Female          20          28
# 1    Male           2          30
# 2  Female           6          28
# 3  Female          12          25
# 4  Female           3          25

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_list = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in treatment_list:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    final_tumor_vol = cleaned_df.loc[cleaned_df["Drug Regimen"] == drug, 'Tumor Volume (mm3)']
    
    # add subset 
    tumor_vol_list.append(final_tumor_vol)
    
    # Determine outliers using upper and lower bounds
    quartiles = final_tumor_vol.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    outliers = final_tumor_vol.loc[(final_tumor_vol < lower_bound) | (final_tumor_vol > upper_bound)]
    print(f"{drug}'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: 1652    25.472143
# 1849    23.343598
# Name: Tumor Volume (mm3), dtype: float64
# Ramicane's potential outliers: 1814    22.050126
# Name: Tumor Volume (mm3), dtype: float64
# Infubinol's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 = plt.subplots(figsize=(7,5))
ax1.set_title('Tumor Volume Across Four Regimens of Interest', fontsize=16)
ax1.set_xlabel('Drug Regimen', fontsize=12)
ax1.set_ylabel('Final Tumor Volume (mm3)', fontsize=12)
ax1.boxplot(tumor_vol_list, labels=treatment_list, sym='r')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
line_chart_df = capomulin_df.loc[capomulin_df['Mouse ID'] == 'l509']

x_axis = line_chart_df['Timepoint']
y_axis = line_chart_df['Tumor Volume (mm3)']

fig1, ax1 = plt.subplots(figsize=(7,5))
plt.plot(x_axis, y_axis, color='blue')
plt.title('Capomulin Treatment of Mouse l509')
plt.xlabel('Timepoint (Days)')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# Calculate average tumor volume and create dataframe
capomulin_df.head()
reduced_cap_df = capomulin_df.loc[:, ['Mouse ID', 'Weight (g)', 'Tumor Volume (mm3)']]
reduced_cap_df.head()
average_capomulin_vol = pd.DataFrame(reduced_cap_df.groupby(['Mouse ID', 'Weight (g)'])['Tumor Volume (mm3)'].mean()).reset_index()
average_capomulin_vol

# Create scatter plot
average_capomulin_vol.plot(kind="scatter", x="Weight (g)", y="Tumor Volume (mm3)", figsize=(7,5))
plt.title('Average Tumor Volume vs Mouse Weight')
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
mouse_weight = average_capomulin_vol.iloc[:,1]
avg_tumor_volume = average_capomulin_vol.iloc[:,2]
correlation = st.pearsonr(mouse_weight, avg_tumor_volume)
print(f'The correlation between both factors is {round(correlation[0],2)}')
# Out:
# The correlation between both factors is 0.84

# %%
# Calculate linear regression
x_values = average_capomulin_vol['Weight (g)']
y_values = average_capomulin_vol['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Mouse Weight')
plt.ylabel('Average Tumor Volume')
plt.show()

# %%
Pymaceuticals Analysis

# %%
# 1. Of the four drugs analyzed, Capomulin proved to be the most successful at reducing tumor volume, and it also seemed 
# to have a significant effect on lowering metatastic spread. This is especially evident when comparing the results shown 
# for Infubinol.

# 2. When looking at the scatter plot 'Average Tumor Volume vs Mouse Weight', there is a clear positive correlation between 
# tumor volume and the weight of the mice that were studied. This should be taken into consideration when thinking about the 
# success of each drug and the weight of the mice in each treatment group. It's possible the average reduction over the treatment 
# is significant even if the actual volume is still fairly large.

# 3. Looking at the 'Number of Mice Per Treatment' bar graph shows that Capomulin and Ramicane both tested the highest number 
# of mice. It's possible having more data allowed their results to be more positive or, alternatively, if Infubinol and Ceftamine 
# tested more mice then perhaps the results would end up changing in some way.
